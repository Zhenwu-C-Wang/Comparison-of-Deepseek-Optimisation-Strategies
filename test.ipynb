# %%
# !pip install transformers datasets torch matplotlib seaborn
# !pip install datasets
# !/Users/wangzhenwu/Documents/Pool/.venv/bin/python -m pip install datasets

# %%
from datasets import load_dataset

dataset = load_dataset("imdb")
train_data = dataset["train"].shuffle(seed=42).select(range(2000))  # 选择 2000 条训练数据
test_data = dataset["test"].shuffle(seed=42).select(range(500))  # 选择 500 条测试数据
# Out:
# /Users/wangzhenwu/Documents/Pool/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Using the latest cached version of the dataset since imdb couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'plain_text' at /Users/wangzhenwu/.cache/huggingface/datasets/imdb/plain_text/0.0.0/e6281661ce1c48d982bc483cf8a173c1bbeb5d31 (last modified on Tue Feb 11 17:48:19 2025).

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer, Trainer, TrainingArguments
import torch

model_name = "distilbert-base-uncased"  # 选择一个简单的 Transformer 模型
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)

def tokenize_function(examples):
    return tokenizer(examples["text"], padding="max_length", truncation=True)

train_data = train_data.map(tokenize_function, batched=True)
test_data = test_data.map(tokenize_function, batched=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Documents/Pool/.venv/lib/python3.9/site-packages/transformers/activations_tf.py:22
#      21 try:
# ---> 22     import tf_keras as keras
#      23 except (ModuleNotFoundError, ImportError):
#
# ModuleNotFoundError: No module named 'tf_keras'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/Documents/Pool/.venv/lib/python3.9/site-packages/transformers/utils/import_utils.py:1793, in _LazyModule._get_module(self, module_name)
#    1792 try:
# -> 1793     return importlib.import_module("." + module_name, self.__name__)
#    1794 except Exception as e:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
# ...
