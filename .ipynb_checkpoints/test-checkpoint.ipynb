# %%
# !pip install transformers datasets torch matplotlib seaborn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 143.5 kB/s eta 0:00:00a 0:00:01
# ...
#   Using cached datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# ...
#   Using cached huggingface_hub-0.28.1-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached tokenizers-0.21.0-cp39-abi3-macosx_10_12_x86_64.whl.metadata (6.7 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 927.1 kB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 7.5 MB/s eta 0:00:0000:0100:01
# Using cached datasets-3.2.0-py3-none-any.whl (480 kB)
# Using cached huggingface_hub-0.28.1-py3-none-any.whl (464 kB)
# Using cached multiprocess-0.70.16-py312-none-any.whl (146 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.1/427.1 kB 10.1 MB/s eta 0:00:0000:01
# ...
